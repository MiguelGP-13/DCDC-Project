# %%
import pandas as pd

# %%
BK = pd.read_csv("BK_Coruna.csv")

# %%
print(BK.shape)
BK.head()
# Out:
# (12383, 21)
#                       place_id   place_name  \
# 0  ChIJs8gvuH98Lg0RMdJXdiTfzsI  Burger King
# 1  ChIJs8gvuH98Lg0RMdJXdiTfzsI  Burger King
# 2  ChIJs8gvuH98Lg0RMdJXdiTfzsI  Burger King
# 3  ChIJs8gvuH98Lg0RMdJXdiTfzsI  Burger King
# 4  ChIJs8gvuH98Lg0RMdJXdiTfzsI  Burger King
#
#                                            review_id  \
# 0  Ci9DQUlRQUNvZENodHljRjlvT21wUFh6WkNiRjlNWldjeF...
# 1  Ci9DQUlRQUNvZENodHljRjlvT2xWbldXdHFhRUkwTlhKWF...
# 2  Ci9DQUlRQUNvZENodHljRjlvT21ob05VaEZhV2RmTldNek...
# 3  Ci9DQUlRQUNvZENodHljRjlvT2psaGRtNVBVa3A1U2paR1...
# 4  Ci9DQUlRQUNvZENodHljRjlvT25OMUxYSkNRVlExZDJoc2...
#
#                                          review_link             name  \
# 0  https://www.google.com/maps/reviews/data=!4m8!...  mariana morillo
# 1  https://www.google.com/maps/reviews/data=!4m8!...          Bat Man
# 2  https://www.google.com/maps/reviews/data=!4m8!...        Francisco
# 3  https://www.google.com/maps/reviews/data=!4m8!...    Maria Grandio
# ...

# %%
BK.isna().sum()
# Out:
# place_id                                  0
# place_name                                0
# review_id                                 0
# review_link                               0
# name                                      0
# reviewer_id                               0
# reviewer_profile                          0
# rating                                    0
# review_text                            6649
# published_at                              0
# published_at_date                         0
# response_from_owner_text               7307
# response_from_owner_ago                7307
# response_from_owner_date               7307
# total_number_of_reviews_by_reviewer       0
# total_number_of_photos_by_reviewer        0
# is_local_guide                         4620
# review_translated_text                 6777
# response_from_owner_translated_text    7344
# experience_details                        0
# review_photos                             0
# dtype: int64

# %%
BK_clean = BK[BK["review_text"].isna() == False]

# %%
print(BK_clean.shape)
BK_clean.head()
# Out:
# (5734, 21)
#                       place_id   place_name  \
# 1  ChIJs8gvuH98Lg0RMdJXdiTfzsI  Burger King
# 2  ChIJs8gvuH98Lg0RMdJXdiTfzsI  Burger King
# 3  ChIJs8gvuH98Lg0RMdJXdiTfzsI  Burger King
# 4  ChIJs8gvuH98Lg0RMdJXdiTfzsI  Burger King
# 5  ChIJs8gvuH98Lg0RMdJXdiTfzsI  Burger King
#
#                                            review_id  \
# 1  Ci9DQUlRQUNvZENodHljRjlvT2xWbldXdHFhRUkwTlhKWF...
# 2  Ci9DQUlRQUNvZENodHljRjlvT21ob05VaEZhV2RmTldNek...
# 3  Ci9DQUlRQUNvZENodHljRjlvT2psaGRtNVBVa3A1U2paR1...
# 4  Ci9DQUlRQUNvZENodHljRjlvT25OMUxYSkNRVlExZDJoc2...
# 5  Ci9DQUlRQUNvZENodHljRjlvT2kxQlNXbFVhR2xEZERKUG...
#
#                                          review_link              name  \
# 1  https://www.google.com/maps/reviews/data=!4m8!...           Bat Man
# 2  https://www.google.com/maps/reviews/data=!4m8!...         Francisco
# 3  https://www.google.com/maps/reviews/data=!4m8!...     Maria Grandio
# 4  https://www.google.com/maps/reviews/data=!4m8!...         Loli LuRo
# ...
