# %%
import re

a = re.compile(r"(\/[ao][s]?)[^A-Za-zÑñ]")

# %%
import re

texto = "alumnos/as: niños/a niños/año"
patrón = re.compile(r"(\/[ao][s]?)([^A-Za-zÑñ])")
nuevo = patrón.sub(r"\2", texto)
print(nuevo)  # "@ # 1"
# Out:
# alumnos niños niños/año
