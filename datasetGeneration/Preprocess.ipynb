# %%
import pandas as pd
from datetime import datetime
import re

from langdetect import detect
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       2 from datetime import datetime
#       3 import re
# ----> 5 from langdetect import detect
#       6 import os
#
# ModuleNotFoundError: No module named 'langdetect'

# %% [markdown]
# ## Analizamos resultados
#
# Vemos que curiosamente la `empresa` y la `duración de jornada` son campos que están vacíos en casi todas las ofertas

# %%
def read_file(path):
    df = pd.read_csv(path)#("ofertas/ofertas11_092659.csv")
    filasNulas = df[df.isna().sum(axis="columns") >= df.shape[1]-1]

    print(f"El dataset tiene {df.shape[0]} ofertas, de las cuales, {filasNulas.shape[0]} están vacías (excepto la url)")
    print("\nNúmero de nulos por columna, excluyendo filas completamente nulas:")
    print(df.isna().sum()[df.isna().sum() > filasNulas.shape[0]] - filasNulas.shape[0])

    return df, df.drop(filasNulas.index)

# %%
clean = read_file("")

# %%
clean["fecha_publicacion"].unique()
# Out:
# array(['11/10/2025', '08/10/2025', '10/10/2025'], dtype=object)

# %%
clean["fecha_limite"].unique()
# Out:
# array(['16/09/2025', '19/11/2025', '15/10/2025', '31/10/2025',
#        '29/10/2025', '16/10/2025', '15/11/2025', '19/10/2025',
#        '21/11/2025', '16/11/2025', '25/10/2025', '30/10/2025',
#        '23/10/2025', '10/10/2025', '11/10/2025', '17/11/2025',
#        '20/10/2025', '18/10/2025', '24/11/2025', '31/12/2025',
#        '22/10/2025', '27/10/2025', '24/10/2025', '21/10/2025',
#        '25/11/2025', '18/11/2025', '20/11/2025', '14/10/2025',
#        '7/11/2025', nan, '11/11/2025', '26/11/2025', '17/10/2025',
#        '26/10/2025', '27/11/2025', '29/11/2025', '1/01/2026',
#        '23/11/2025', '28/11/2025', '29/12/2025', '13/10/2025',
#        '28/10/2025', '26/10/2026', '1/12/2025', '2/11/2025', '30/12/2025',
#        '2/12/2025', '1/11/2025', '3/11/2025', '12/10/2025', '5/12/2025',
#        '3/12/2025', '4/12/2025', '4/11/2025', '30/11/2025', '7/12/2025',
#        '8/12/2025', '11/12/2025', '9/12/2025', '8/11/2025', '10/12/2025',
#        '10/11/2025', '9/11/2025', '6/11/2025', '30/01/2026', '12/12/2025',
#        '13/12/2025', '15/12/2025', '14/11/2025', '16/12/2025',
#        '12/11/2025', '17/12/2025', '18/12/2025', '21/03/2026',
#        '19/12/2025', '14/12/2025', '22/12/2025', '23/12/2025',
#        '21/12/2025', '22/11/2025', '24/12/2025', '25/12/2025',
#        '26/12/2025', '31/10/2026', '2/01/2026', '28/12/2025', '3/01/2026',
#        '5/11/2025', '4/01/2026', '4/03/2026', '5/01/2026', '6/01/2026',
#        '7/01/2026', '6/12/2025', '27/03/2026', '15/01/2026', '15/02/2026',
#        '13/11/2025'], dtype=object)

# %%
clean_es = clean[clean['descripcion'].apply(lambda r: detect(r) == 'es')]
clean.shape, clean_es.shape
# Out:
# ((9685, 12), (7435, 12))

# %%
clean_es.to_csv("ofertasRaw.csv")

# %% [markdown]
# ## Gestionar valores duplicados y NaN

# %%
clean = pd.read_csv("ofertasRaw.csv").drop(["Unnamed: 0"], axis="columns")
clean.drop_duplicates(subset=['url'], inplace=True)
clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
clean.set_index("url")
# Out:
#                                                    fecha_publicacion  \
# url
# https://europa.eu/eures/portal/jv-se/jv-details...        10/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...        10/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...        10/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...        10/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...        10/10/2025
# ...                                                              ...
# https://europa.eu/eures/portal/jv-se/jv-details...        11/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...        11/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...        11/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...        10/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...        11/10/2025
#
#                                                    fecha_limite  \
# url
# https://europa.eu/eures/portal/jv-se/jv-details...   31/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...   10/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...   24/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...   13/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...   20/10/2025
# ...                                                         ...
# https://europa.eu/eures/portal/jv-se/jv-details...   20/11/2025
# https://europa.eu/eures/portal/jv-se/jv-details...   20/11/2025
# https://europa.eu/eures/portal/jv-se/jv-details...   20/11/2025
# https://europa.eu/eures/portal/jv-se/jv-details...   22/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...   13/10/2025
#
#                                                                                                titulo  \
# url
# https://europa.eu/eures/portal/jv-se/jv-details...                  CONDUCTORES DE CAMIÓN, EN GENERAL
# https://europa.eu/eures/portal/jv-se/jv-details...                                      WORK/LOCATION
# https://europa.eu/eures/portal/jv-se/jv-details...                                      WORK/LOCATION
# https://europa.eu/eures/portal/jv-se/jv-details...                                      WORK/LOCATION
# https://europa.eu/eures/portal/jv-se/jv-details...                                      WORK/LOCATION
# ...                                                                                               ...
# https://europa.eu/eures/portal/jv-se/jv-details...                                      WORK/LOCATION
# https://europa.eu/eures/portal/jv-se/jv-details...                                      WORK/LOCATION
# https://europa.eu/eures/portal/jv-se/jv-details...                                      WORK/LOCATION
# https://europa.eu/eures/portal/jv-se/jv-details...  MONITOR/A ROBÓTICA EDUCATIVA - LLANES Y CANGAS...
# https://europa.eu/eures/portal/jv-se/jv-details...                        DOCENTE PARA IMPARTIR CURSO
#
#                                                    empresa  \
# url
# https://europa.eu/eures/portal/jv-se/jv-details...     NaN
# https://europa.eu/eures/portal/jv-se/jv-details...     NaN
# https://europa.eu/eures/portal/jv-se/jv-details...     NaN
# https://europa.eu/eures/portal/jv-se/jv-details...     NaN
# https://europa.eu/eures/portal/jv-se/jv-details...     NaN
# ...                                                    ...
# https://europa.eu/eures/portal/jv-se/jv-details...     NaN
# https://europa.eu/eures/portal/jv-se/jv-details...     NaN
# https://europa.eu/eures/portal/jv-se/jv-details...     NaN
# https://europa.eu/eures/portal/jv-se/jv-details...     NaN
# https://europa.eu/eures/portal/jv-se/jv-details...     NaN
#
#                                                                                             ocupacion  \
# url
# https://europa.eu/eures/portal/jv-se/jv-details...  Conductor de vehículo de carga/conductora de v...
# https://europa.eu/eures/portal/jv-se/jv-details...  Empleado administrativo de archivos/empleada a...
# https://europa.eu/eures/portal/jv-se/jv-details...  Operario especializado en engranajes de automo...
# https://europa.eu/eures/portal/jv-se/jv-details...              Empleado del hogar/empleada del hogar
# https://europa.eu/eures/portal/jv-se/jv-details...  Conductor de servicios de transporte de enferm...
# ...                                                                                               ...
# https://europa.eu/eures/portal/jv-se/jv-details...  Inspector de carga y flete/inspectora de carga...
# https://europa.eu/eures/portal/jv-se/jv-details...   Profesor de autoescuela/profesora de autoescuela
# https://europa.eu/eures/portal/jv-se/jv-details...                   Mayordomo del servicio doméstico
# https://europa.eu/eures/portal/jv-se/jv-details...  Maestro de educación primaria/maestra de educa...
# https://europa.eu/eures/portal/jv-se/jv-details...                                                NaN
#
#                                                       educacion  \
# url
# https://europa.eu/eures/portal/jv-se/jv-details...     Contrato
# https://europa.eu/eures/portal/jv-se/jv-details...     Contrato
# https://europa.eu/eures/portal/jv-se/jv-details...     Contrato
# https://europa.eu/eures/portal/jv-se/jv-details...     Contrato
# https://europa.eu/eures/portal/jv-se/jv-details...  Determinado
# ...                                                         ...
# https://europa.eu/eures/portal/jv-se/jv-details...  Determinado
# https://europa.eu/eures/portal/jv-se/jv-details...     Autónomo
# https://europa.eu/eures/portal/jv-se/jv-details...     Contrato
# https://europa.eu/eures/portal/jv-se/jv-details...  Determinado
# https://europa.eu/eures/portal/jv-se/jv-details...  Determinado
#
#                                                                                           descripcion  \
# url
# https://europa.eu/eures/portal/jv-se/jv-details...  REQUIERE ESTAR EN POSESIÓN DEL CAP. LA EMPRESA...
# https://europa.eu/eures/portal/jv-se/jv-details...  ES BUSCA UNA PERSONA AMB ESTUDIS I EXPERIèNCIA...
# https://europa.eu/eures/portal/jv-se/jv-details...  CERQUEM PROFESSIONALS AMB EXPERIèNCIA EN MUNTA...
# https://europa.eu/eures/portal/jv-se/jv-details...  IMPORTANTE EMPRESA UBICADA EN MERCABARNA PRECI...
# https://europa.eu/eures/portal/jv-se/jv-details...  REQUISITS: ? TITULACIÓ D? ESPECIALISTA EN FARM...
# ...                                                                                               ...
# https://europa.eu/eures/portal/jv-se/jv-details...  ACTUALMENTE, DESDE LA DELEGACIÓN DE TARRAGONA ...
# https://europa.eu/eures/portal/jv-se/jv-details...  NDICE CONSULTORÍA Y FORMACIÓN, SOMOS UNA CONSU...
# https://europa.eu/eures/portal/jv-se/jv-details...  HELPOINT -ÉS UNA CONSULTORIA ÚNICA ESPECIALITZ...
# https://europa.eu/eures/portal/jv-se/jv-details...  FUNCIONES: Preparar actividades y proyectos di...
# https://europa.eu/eures/portal/jv-se/jv-details...  IMPARTIR MÓDULOS: - OFIMÁTICA - INICIACIÓN A I...
#
#                                                       pais       region  \
# url
# https://europa.eu/eures/portal/jv-se/jv-details...  España   Palencia -
# https://europa.eu/eures/portal/jv-se/jv-details...  España  Tarragona -
# https://europa.eu/eures/portal/jv-se/jv-details...  España     Girona -
# https://europa.eu/eures/portal/jv-se/jv-details...  España  Barcelona -
# https://europa.eu/eures/portal/jv-se/jv-details...  España  Barcelona -
# ...                                                    ...          ...
# https://europa.eu/eures/portal/jv-se/jv-details...  España  Barcelona -
# https://europa.eu/eures/portal/jv-se/jv-details...  España  Barcelona -
# https://europa.eu/eures/portal/jv-se/jv-details...  España  Barcelona -
# https://europa.eu/eures/portal/jv-se/jv-details...  España   Asturias -
# https://europa.eu/eures/portal/jv-se/jv-details...  España   Albacete -
#
#                                                     duracion_jornada  \
# url
# https://europa.eu/eures/portal/jv-se/jv-details...               NaN
# https://europa.eu/eures/portal/jv-se/jv-details...               NaN
# https://europa.eu/eures/portal/jv-se/jv-details...               NaN
# https://europa.eu/eures/portal/jv-se/jv-details...               NaN
# https://europa.eu/eures/portal/jv-se/jv-details...               NaN
# ...                                                              ...
# https://europa.eu/eures/portal/jv-se/jv-details...               NaN
# https://europa.eu/eures/portal/jv-se/jv-details...               NaN
# https://europa.eu/eures/portal/jv-se/jv-details...               NaN
# https://europa.eu/eures/portal/jv-se/jv-details...               NaN
# https://europa.eu/eures/portal/jv-se/jv-details...               NaN
#
#                                                    tipo_contrato
# url
# https://europa.eu/eures/portal/jv-se/jv-details...      Contrato
# https://europa.eu/eures/portal/jv-se/jv-details...      Contrato
# https://europa.eu/eures/portal/jv-se/jv-details...      Contrato
# https://europa.eu/eures/portal/jv-se/jv-details...      Contrato
# https://europa.eu/eures/portal/jv-se/jv-details...   Determinado
# ...                                                          ...
# https://europa.eu/eures/portal/jv-se/jv-details...   Determinado
# https://europa.eu/eures/portal/jv-se/jv-details...      Autónomo
# https://europa.eu/eures/portal/jv-se/jv-details...      Contrato
# https://europa.eu/eures/portal/jv-se/jv-details...   Determinado
# https://europa.eu/eures/portal/jv-se/jv-details...   Determinado
#
# [7305 rows x 11 columns]

# %%
clean.isna().sum()
# Out:
# url                     0
# fecha_publicacion       0
# fecha_limite            6
# titulo                  0
# empresa              7241
# ocupacion             735
# educacion               0
# descripcion             0
# pais                    0
# region                115
# duracion_jornada     7305
# tipo_contrato           2
# dtype: int64

# %% [markdown]
# Hay que borrar filas de fecha nula

# %%
clean.dropna(subset="fecha_limite", inplace=True)

# %%
def cleanDash(region):
    if type(region) == str:
        if region[-1] == "-":
            region = region[:-1]
        return region.strip()
    return region

clean["region"] = clean["region"].apply(cleanDash)

# %%
clean.head()
# Out:
#                                                  url fecha_publicacion  \
# 0  https://europa.eu/eures/portal/jv-se/jv-detail...        10/10/2025
# 1  https://europa.eu/eures/portal/jv-se/jv-detail...        10/10/2025
# 2  https://europa.eu/eures/portal/jv-se/jv-detail...        10/10/2025
# 3  https://europa.eu/eures/portal/jv-se/jv-detail...        10/10/2025
# 4  https://europa.eu/eures/portal/jv-se/jv-detail...        10/10/2025
#
#   fecha_limite                             titulo empresa  \
# 0   31/10/2025  CONDUCTORES DE CAMIÓN, EN GENERAL     NaN
# 1   10/10/2025                      WORK/LOCATION     NaN
# 2   24/10/2025                      WORK/LOCATION     NaN
# 3   13/10/2025                      WORK/LOCATION     NaN
# 4   20/10/2025                      WORK/LOCATION     NaN
#
#                                            ocupacion    educacion  \
# 0  Conductor de vehículo de carga/conductora de v...     Contrato
# 1  Empleado administrativo de archivos/empleada a...     Contrato
# 2  Operario especializado en engranajes de automo...     Contrato
# 3              Empleado del hogar/empleada del hogar     Contrato
# 4  Conductor de servicios de transporte de enferm...  Determinado
#
#                                          descripcion    pais     region  \
# 0  REQUIERE ESTAR EN POSESIÓN DEL CAP. LA EMPRESA...  España   Palencia
# 1  ES BUSCA UNA PERSONA AMB ESTUDIS I EXPERIèNCIA...  España  Tarragona
# 2  CERQUEM PROFESSIONALS AMB EXPERIèNCIA EN MUNTA...  España     Girona
# 3  IMPORTANTE EMPRESA UBICADA EN MERCABARNA PRECI...  España  Barcelona
# 4  REQUISITS: ? TITULACIÓ D? ESPECIALISTA EN FARM...  España  Barcelona
#
#    duracion_jornada tipo_contrato
# 0               NaN      Contrato
# 1               NaN      Contrato
# 2               NaN      Contrato
# 3               NaN      Contrato
# 4               NaN   Determinado

# %% [markdown]
# ### Columnas sin informacion

# %%
clean.set_index("url", inplace= True)
clean.drop(["educacion", "duracion_jornada", "empresa"], inplace= True, axis="columns")
clean.shape
# Out:
# (7299, 9)

# %%
clean.head()
# Out:
#                                                    fecha_publicacion  \
# url
# https://europa.eu/eures/portal/jv-se/jv-details...        10/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...        10/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...        10/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...        10/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...        10/10/2025
#
#                                                    fecha_limite  \
# url
# https://europa.eu/eures/portal/jv-se/jv-details...   31/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...   10/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...   24/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...   13/10/2025
# https://europa.eu/eures/portal/jv-se/jv-details...   20/10/2025
#
#                                                                                titulo  \
# url
# https://europa.eu/eures/portal/jv-se/jv-details...  CONDUCTORES DE CAMIÓN, EN GENERAL
# https://europa.eu/eures/portal/jv-se/jv-details...                      WORK/LOCATION
# https://europa.eu/eures/portal/jv-se/jv-details...                      WORK/LOCATION
# https://europa.eu/eures/portal/jv-se/jv-details...                      WORK/LOCATION
# https://europa.eu/eures/portal/jv-se/jv-details...                      WORK/LOCATION
#
#                                                    empresa  \
# url
# https://europa.eu/eures/portal/jv-se/jv-details...     NaN
# https://europa.eu/eures/portal/jv-se/jv-details...     NaN
# https://europa.eu/eures/portal/jv-se/jv-details...     NaN
# https://europa.eu/eures/portal/jv-se/jv-details...     NaN
# https://europa.eu/eures/portal/jv-se/jv-details...     NaN
#
#                                                                                             ocupacion  \
# url
# https://europa.eu/eures/portal/jv-se/jv-details...  Conductor de vehículo de carga/conductora de v...
# https://europa.eu/eures/portal/jv-se/jv-details...  Empleado administrativo de archivos/empleada a...
# https://europa.eu/eures/portal/jv-se/jv-details...  Operario especializado en engranajes de automo...
# https://europa.eu/eures/portal/jv-se/jv-details...              Empleado del hogar/empleada del hogar
# https://europa.eu/eures/portal/jv-se/jv-details...  Conductor de servicios de transporte de enferm...
#
#                                                                                           descripcion  \
# url
# https://europa.eu/eures/portal/jv-se/jv-details...  REQUIERE ESTAR EN POSESIÓN DEL CAP. LA EMPRESA...
# https://europa.eu/eures/portal/jv-se/jv-details...  ES BUSCA UNA PERSONA AMB ESTUDIS I EXPERIèNCIA...
# https://europa.eu/eures/portal/jv-se/jv-details...  CERQUEM PROFESSIONALS AMB EXPERIèNCIA EN MUNTA...
# https://europa.eu/eures/portal/jv-se/jv-details...  IMPORTANTE EMPRESA UBICADA EN MERCABARNA PRECI...
# https://europa.eu/eures/portal/jv-se/jv-details...  REQUISITS: ? TITULACIÓ D? ESPECIALISTA EN FARM...
#
#                                                       pais     region  \
# url
# https://europa.eu/eures/portal/jv-se/jv-details...  España   Palencia
# https://europa.eu/eures/portal/jv-se/jv-details...  España  Tarragona
# https://europa.eu/eures/portal/jv-se/jv-details...  España     Girona
# https://europa.eu/eures/portal/jv-se/jv-details...  España  Barcelona
# https://europa.eu/eures/portal/jv-se/jv-details...  España  Barcelona
#
#                                                    tipo_contrato
# url
# https://europa.eu/eures/portal/jv-se/jv-details...      Contrato
# https://europa.eu/eures/portal/jv-se/jv-details...      Contrato
# https://europa.eu/eures/portal/jv-se/jv-details...      Contrato
# https://europa.eu/eures/portal/jv-se/jv-details...      Contrato
# https://europa.eu/eures/portal/jv-se/jv-details...   Determinado

# %%
clean.to_csv("ofertas.csv")

# %% [markdown]
# ## Análisis títulos repetidos

# %%
clean = pd.read_csv("ofertas.csv")
clean["titulo"].value_counts()
# Out:
# titulo
# WORK/LOCATION                                              3562
# PERSONAL DE LIMPIEZA O LIMPIADORES EN GENERAL               110
# CONDUCTORES DE CAMIÓN, EN GENERAL                            82
# COCINEROS, EN GENERAL                                        68
# ENFERMEROS DE CUIDADOS GENERALES                             62
#                                                            ...
# CAMARERO/A (REF.5904)                                         1
# MOZO ALMACEN//REPARTIDOR                                      1
# MONTADORES DE GRANDES ESTRUCTURAS METÁLICAS, EN GENERAL       1
# AUXILIARES DE ENFERMERIA/GERIATRIA                            1
# AUXILIAR DE AYUDA A DOMICILIO - PILOÑA                        1
# Name: count, Length: 1923, dtype: int64

# %%
descriptiveName = clean[clean["titulo"] != "WORK/LOCATION"]
descriptiveName.shape
# Out:
# (3737, 10)

# %%
fechas = pd.to_datetime(descriptiveName.fecha_limite.unique(), dayfirst=True)

# %%
sorted(fechas)
# Out:
# [Timestamp('2025-10-10 00:00:00'),
#  Timestamp('2025-10-11 00:00:00'),
#  Timestamp('2025-10-12 00:00:00'),
#  Timestamp('2025-10-13 00:00:00'),
#  Timestamp('2025-10-14 00:00:00'),
#  Timestamp('2025-10-15 00:00:00'),
#  Timestamp('2025-10-16 00:00:00'),
#  Timestamp('2025-10-17 00:00:00'),
#  Timestamp('2025-10-18 00:00:00'),
#  Timestamp('2025-10-19 00:00:00'),
#  Timestamp('2025-10-20 00:00:00'),
#  Timestamp('2025-10-21 00:00:00'),
#  Timestamp('2025-10-22 00:00:00'),
#  Timestamp('2025-10-23 00:00:00'),
#  Timestamp('2025-10-24 00:00:00'),
#  Timestamp('2025-10-25 00:00:00'),
#  Timestamp('2025-10-26 00:00:00'),
#  Timestamp('2025-10-27 00:00:00'),
#  Timestamp('2025-10-28 00:00:00'),
#  Timestamp('2025-10-29 00:00:00'),
#  Timestamp('2025-10-30 00:00:00'),
#  Timestamp('2025-10-31 00:00:00'),
#  Timestamp('2025-11-01 00:00:00'),
#  Timestamp('2025-11-02 00:00:00'),
#  Timestamp('2025-11-03 00:00:00'),
#  Timestamp('2025-11-04 00:00:00'),
#  Timestamp('2025-11-05 00:00:00'),
#  Timestamp('2025-11-06 00:00:00'),
#  Timestamp('2025-11-07 00:00:00'),
#  Timestamp('2025-11-08 00:00:00'),
#  Timestamp('2025-11-09 00:00:00'),
#  Timestamp('2025-11-10 00:00:00'),
#  Timestamp('2025-11-11 00:00:00'),
#  Timestamp('2025-11-12 00:00:00'),
#  Timestamp('2025-11-13 00:00:00'),
#  Timestamp('2025-11-14 00:00:00'),
#  Timestamp('2025-11-15 00:00:00'),
#  Timestamp('2025-11-16 00:00:00'),
#  Timestamp('2025-11-17 00:00:00'),
#  Timestamp('2025-11-18 00:00:00'),
#  Timestamp('2025-11-19 00:00:00'),
#  Timestamp('2025-11-20 00:00:00'),
#  Timestamp('2025-11-21 00:00:00'),
#  Timestamp('2025-11-22 00:00:00'),
#  Timestamp('2025-11-23 00:00:00'),
#  Timestamp('2025-11-24 00:00:00'),
#  Timestamp('2025-11-25 00:00:00'),
#  Timestamp('2025-11-26 00:00:00'),
#  Timestamp('2025-11-27 00:00:00'),
#  Timestamp('2025-11-28 00:00:00'),
#  Timestamp('2025-11-29 00:00:00'),
#  Timestamp('2025-11-30 00:00:00'),
#  Timestamp('2025-12-01 00:00:00'),
#  Timestamp('2025-12-02 00:00:00'),
#  Timestamp('2025-12-03 00:00:00'),
#  Timestamp('2025-12-04 00:00:00'),
#  Timestamp('2025-12-05 00:00:00'),
#  Timestamp('2025-12-06 00:00:00'),
#  Timestamp('2025-12-07 00:00:00'),
#  Timestamp('2025-12-08 00:00:00'),
#  Timestamp('2025-12-09 00:00:00'),
#  Timestamp('2025-12-10 00:00:00'),
#  Timestamp('2025-12-11 00:00:00'),
#  Timestamp('2025-12-12 00:00:00'),
#  Timestamp('2025-12-13 00:00:00'),
#  Timestamp('2025-12-14 00:00:00'),
#  Timestamp('2025-12-15 00:00:00'),
#  Timestamp('2025-12-16 00:00:00'),
#  Timestamp('2025-12-17 00:00:00'),
#  Timestamp('2025-12-18 00:00:00'),
#  Timestamp('2025-12-19 00:00:00'),
#  Timestamp('2025-12-20 00:00:00'),
#  Timestamp('2025-12-21 00:00:00'),
#  Timestamp('2025-12-22 00:00:00'),
#  Timestamp('2025-12-23 00:00:00'),
#  Timestamp('2025-12-24 00:00:00'),
#  Timestamp('2025-12-25 00:00:00'),
#  Timestamp('2025-12-26 00:00:00'),
#  Timestamp('2025-12-28 00:00:00'),
#  Timestamp('2025-12-29 00:00:00'),
#  Timestamp('2025-12-30 00:00:00'),
#  Timestamp('2025-12-31 00:00:00'),
#  Timestamp('2026-01-01 00:00:00'),
#  Timestamp('2026-01-03 00:00:00'),
#  Timestamp('2026-01-04 00:00:00'),
#  Timestamp('2026-01-05 00:00:00'),
#  Timestamp('2026-01-06 00:00:00'),
#  Timestamp('2026-01-07 00:00:00'),
#  Timestamp('2026-01-15 00:00:00'),
#  Timestamp('2026-01-23 00:00:00'),
#  Timestamp('2026-02-05 00:00:00'),
#  Timestamp('2026-02-15 00:00:00'),
#  Timestamp('2026-02-25 00:00:00'),
#  Timestamp('2026-03-02 00:00:00'),
#  Timestamp('2026-03-04 00:00:00'),
#  Timestamp('2026-03-21 00:00:00'),
#  Timestamp('2026-10-26 00:00:00')]

# %%
descriptiveName.set_index("url", inplace= True)
descriptiveName.shape
# Out:
# (3737, 9)

# %%
descriptiveName.to_csv("ofertasDescriptive.csv")

# %%
set(pd.to_datetime(clean.fecha_limite.unique(), dayfirst=True)) - set(pd.to_datetime(descriptiveName.fecha_limite.unique(), dayfirst=True))
# Out:
# {Timestamp('2026-01-02 00:00:00')}

# %%
clean[clean["titulo"] == "WORK/LOCATION"]
# Out:
#                                                     url fecha_publicacion  \
# 1     https://europa.eu/eures/portal/jv-se/jv-detail...        10/10/2025
# 2     https://europa.eu/eures/portal/jv-se/jv-detail...        10/10/2025
# 3     https://europa.eu/eures/portal/jv-se/jv-detail...        10/10/2025
# 4     https://europa.eu/eures/portal/jv-se/jv-detail...        10/10/2025
# 6     https://europa.eu/eures/portal/jv-se/jv-detail...        10/10/2025
# ...                                                 ...               ...
# 7292  https://europa.eu/eures/portal/jv-se/jv-detail...        11/10/2025
# 7293  https://europa.eu/eures/portal/jv-se/jv-detail...        11/10/2025
# 7294  https://europa.eu/eures/portal/jv-se/jv-detail...        11/10/2025
# 7295  https://europa.eu/eures/portal/jv-se/jv-detail...        11/10/2025
# 7296  https://europa.eu/eures/portal/jv-se/jv-detail...        11/10/2025
#
#      fecha_limite         titulo empresa  \
# 1      10/10/2025  WORK/LOCATION     NaN
# 2      24/10/2025  WORK/LOCATION     NaN
# 3      13/10/2025  WORK/LOCATION     NaN
# 4      20/10/2025  WORK/LOCATION     NaN
# 6      20/10/2025  WORK/LOCATION     NaN
# ...           ...            ...     ...
# 7292   20/11/2025  WORK/LOCATION     NaN
# 7293   20/11/2025  WORK/LOCATION     NaN
# 7294   20/11/2025  WORK/LOCATION     NaN
# 7295   20/11/2025  WORK/LOCATION     NaN
# 7296   20/11/2025  WORK/LOCATION     NaN
#
#                                               ocupacion  \
# 1     Empleado administrativo de archivos/empleada a...
# 2     Operario especializado en engranajes de automo...
# 3                 Empleado del hogar/empleada del hogar
# 4     Conductor de servicios de transporte de enferm...
# 6     Conductor de servicios de transporte de enferm...
# ...                                                 ...
# 7292              Empleado del hogar/empleada del hogar
# 7293                    Mozo de almacén/moza de almacén
# 7294  Inspector de carga y flete/inspectora de carga...
# 7295   Profesor de autoescuela/profesora de autoescuela
# 7296                   Mayordomo del servicio doméstico
#
#                                             descripcion    pais     region  \
# 1     ES BUSCA UNA PERSONA AMB ESTUDIS I EXPERIèNCIA...  España  Tarragona
# 2     CERQUEM PROFESSIONALS AMB EXPERIèNCIA EN MUNTA...  España     Girona
# 3     IMPORTANTE EMPRESA UBICADA EN MERCABARNA PRECI...  España  Barcelona
# 4     REQUISITS: ? TITULACIÓ D? ESPECIALISTA EN FARM...  España  Barcelona
# 6     T?AGRADARIA TREBALLAR A LA FUNDACIÓ LAFACT ?LA...  España  Barcelona
# ...                                                 ...     ...        ...
# 7292  CONTRACTE DE SUBSTITUCIÓ PER MATERNITAT PER UN...  España  Tarragona
# 7293  EMPRESA DE SERVICIOS AUXILIARES NECESITA PERSO...  España  Barcelona
# 7294  ACTUALMENTE, DESDE LA DELEGACIÓN DE TARRAGONA ...  España  Barcelona
# 7295  NDICE CONSULTORÍA Y FORMACIÓN, SOMOS UNA CONSU...  España  Barcelona
# 7296  HELPOINT -ÉS UNA CONSULTORIA ÚNICA ESPECIALITZ...  España  Barcelona
#
#      tipo_contrato
# 1         Contrato
# 2         Contrato
# 3         Contrato
# 4      Determinado
# 6         Contrato
# ...            ...
# 7292   Determinado
# 7293      Contrato
# 7294   Determinado
# 7295      Autónomo
# 7296      Contrato
#
# [3562 rows x 10 columns]

# %%
clean["ocupacion"].value_counts()
# Out:
# ocupacion
# Empleado del hogar/empleada del hogar                    306
# Mozo de almacén/moza de almacén                          251
# Barrendero/barrendera                                    248
# Empleado de oficina/empleada de oficina                  214
# Auxiliar de enfermería                                   190
#                                                         ...
# Técnico agrícola/técnica agrícola                          1
# técnico en geología/técnica en geología                    1
# Agente de conservación forestal                            1
# supervisor de destilería/supervisora de destilería         1
# ingeniero técnico agrícola/ingeniera técnica agrícola      1
# Name: count, Length: 463, dtype: int64

# %% [markdown]
# Pese a que no todos las ofertas tienen título, si tienen ocupación, por lo que se puede usar para clasificar aparte del título.
#
#
# Aun así, lo guardamos en 2 csv:
# - `ofertas.csv`: Todas las 7299 ofertas, 3562 sin título
# - `ofertasDescriptive.csv`: Solo las 3737 ofertas con nombre descriptivo

# %%
clean.isna().sum()  / 7299 *100
# Out:
# url                   0.000000
# fecha_publicacion     0.000000
# fecha_limite          0.000000
# titulo                0.000000
# empresa              99.205371
# ocupacion            10.056172
# descripcion           0.000000
# pais                  0.000000
# region                1.561858
# tipo_contrato         0.027401
# dtype: float64

# %% [markdown]
# ## Anonimización de la base de datos

# %% [markdown]
# Para cumplir con los principios FAIR es necesario anonimizar la base de datos, que en nuestro caso corresponde con eliminar los correos electrónicos y números de teléfono presentes en los datos.

# %%
clean = pd.read_csv("ofertas.csv")
clean["titulo"].value_counts()
# Out:
# titulo
# WORK/LOCATION                                              3562
# PERSONAL DE LIMPIEZA O LIMPIADORES EN GENERAL               110
# CONDUCTORES DE CAMIÓN, EN GENERAL                            82
# COCINEROS, EN GENERAL                                        68
# ENFERMEROS DE CUIDADOS GENERALES                             62
#                                                            ...
# CAMARERO/A (REF.5904)                                         1
# MOZO ALMACEN//REPARTIDOR                                      1
# MONTADORES DE GRANDES ESTRUCTURAS METÁLICAS, EN GENERAL       1
# AUXILIARES DE ENFERMERIA/GERIATRIA                            1
# AUXILIAR DE AYUDA A DOMICILIO - PILOÑA                        1
# Name: count, Length: 1923, dtype: int64

# %%
# expresiones regulares
email_regex = re.compile(
    r"""[a-zA-Z0-9.!#$%&'*+/=?^_`{|}~-]+@
        [a-zA-Z0-9-]+(?:\.[a-zA-Z0-9-]+)+""",
    flags=re.VERBOSE | re.IGNORECASE
)

phone_regex_spain = re.compile(
    r"(?:\+34\s?)?(?:6|7|8|9)\d{8}\b"      
)

# buscar coincidencias en el DataFrame
def find_pii(df: pd.DataFrame, target_col: str = "descripcion"):
    """
    Busca correos y teléfonos del DataFrame.
    """
    hits = []
    ser = df[target_col].astype(str).fillna("")

    # emails
    mask_email = ser.str.contains(email_regex, regex=True, na=False)
    for idx in df.index[mask_email]:
        matches = re.findall(email_regex, df.at[idx, target_col])
        for match in matches:
            hits.append((idx, target_col, "email", match))

    # teléfonos
    mask_phone_spain = ser.str.contains(phone_regex_spain, regex=True, na=False)
    for idx in df.index[mask_phone_spain]:
        matches = re.findall(phone_regex_spain, df.at[idx, target_col])
        for match in matches:
            hits.append((idx, target_col, "phone_spain", match))

    # devolver resultados como DataFrame
    result = pd.DataFrame(hits, columns=["index", "column", "type", "match"])
    return result

find_pii(clean)
# Out:
#       index       column         type                              match
# 0        13  descripcion        email  ECYLDOCTORFLEMING.OFERTAS@JCYL.ES
# 1        16  descripcion        email  ECYLDOCTORFLEMING.OFERTAS@JCYL.ES
# 2        19  descripcion        email     laboral@grupoperezespinosa.com
# 3        20  descripcion        email          inaem.oebinefar@aragon.es
# 4        50  descripcion        email          inaem.oebinefar@aragon.es
# ...     ...          ...          ...                                ...
# 2989   6845  descripcion  phone_spain                          976216157
# 2990   6975  descripcion  phone_spain                          987249530
# 2991   7008  descripcion  phone_spain                          987249530
# 2992   7116  descripcion  phone_spain                          976216157
# 2993   7214  descripcion  phone_spain                          976216157
#
# [2994 rows x 4 columns]

# %%
# función para anonimizar el DataFrame
def anonymize_df(df: pd.DataFrame, target_col: str = "descripcion", replace_email: str = "[EMAIL]", replace_phone: str = "[PHONE]"):
    """
    Anonimiza  la columna indicada reemplazando correos y teléfonos por etiquetas.
    """
    df2 = df.copy()

    if pd.api.types.is_string_dtype(df2[target_col]) or pd.api.types.is_object_dtype(df2[target_col]):
        df2[target_col] = df2[target_col].astype(str)
        #  correos
        df2[target_col] = df2[target_col].str.replace(email_regex, replace_email, regex=True)
        #  teléfonos
        df2[target_col] = df2[target_col].str.replace(phone_regex_spain, replace_phone, regex=True)
    return df2


anonim=anonymize_df(clean)

# %%
anonim.to_csv("ofertasAnonimizado.csv",index=False)
